# %% [markdown]
# <a href="https://colab.research.google.com/github/UmangSonika/SDE/blob/main/Notebook_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install google-play-scraper

# %%
import seaborn
from google_play_scraper import app
import pandas as pd
import numpy as np
from google_play_scraper import Sort, reviews_all

# %%
reviews_final = reviews_all(
    'com.sportstoday',sleep_milliseconds=0, lang='en', country='us', sort=Sort.NEWEST,
)

df = pd.DataFrame(np.array(reviews_final),columns=['review'])
df = df.join(pd.DataFrame(df.pop('review').tolist()))

new_df=df[['content', 'score']]
new_df['package'] = 'com.sportstoday'
new_df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#                                              content  score          package
# 0                                   Good application      5  com.sportstoday
# 1                                  Working very slow      1  com.sportstoday
# 2  Love from Nepal Vikrant sir&whole team of spor...      5  com.sportstoday
# 3                                                Kgf      5  com.sportstoday
# 4                                  Luv u vikrant sir      5  com.sportstoday

# %%
new_df['category'] = 'Sports'
new_df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                              content  score          package  \
# 0                                   Good application      5  com.sportstoday
# 1                                  Working very slow      1  com.sportstoday
# 2  Love from Nepal Vikrant sir&whole team of spor...      5  com.sportstoday
# 3                                                Kgf      5  com.sportstoday
# 4                                  Luv u vikrant sir      5  com.sportstoday
#
#   category
# 0   Sports
# 1   Sports
# 2   Sports
# 3   Sports
# 4   Sports

# %%
reviews_final2 = reviews_all(
    'air.au.com.minimega.bonza',sleep_milliseconds=0, lang='en', country='us', sort=Sort.NEWEST,
)

df2 = pd.DataFrame(np.array(reviews_final2),columns=['review'])
df2 = df2.join(pd.DataFrame(df2.pop('review').tolist()))

new_df2=df2[['content', 'score']]
new_df2['package'] = 'air.au.com.minimega.bonza'
new_df2.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#                                              content  score  \
# 0                              very difficult levels      1
# 1                                         Great fun.      5
# 2  The hints that the puzzles are named after are...      2
# 3                                                Fun      5
# 4  I am absolutely loving this game. I am obsesse...      5
#
#                      package
# 0  air.au.com.minimega.bonza
# 1  air.au.com.minimega.bonza
# 2  air.au.com.minimega.bonza
# 3  air.au.com.minimega.bonza
# 4  air.au.com.minimega.bonza

# %%
new_df2['category'] = 'Finance'
new_df2.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                              content  score  \
# 0                              very difficult levels      1
# 1                                         Great fun.      5
# 2  The hints that the puzzles are named after are...      2
# 3                                                Fun      5
# 4  I am absolutely loving this game. I am obsesse...      5
#
#                      package category
# 0  air.au.com.minimega.bonza  Finance
# 1  air.au.com.minimega.bonza  Finance
# 2  air.au.com.minimega.bonza  Finance
# 3  air.au.com.minimega.bonza  Finance
# ...

# %%
reviews_final3 = reviews_all(
    'com.realbyteapps.moneymanagerfree',sleep_milliseconds=0, lang='en', country='us', sort=Sort.NEWEST,
)

df3 = pd.DataFrame(np.array(reviews_final3),columns=['review'])
df3 = df3.join(pd.DataFrame(df3.pop('review').tolist()))

new_df3=df3[['content', 'score']]
new_df3['package'] = 'com.realbyteapps.moneymanagerfree'
new_df3.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#                                              content  score  \
# 0  Love the app. Just one suggestion. If we were ...      4
# 1                                      ดีมากๆเลยครับ      5
# 2  It's very much flexible and user friendly.. Lo...      5
# 3                                     Love it so far      5
# 4  Nice app however it does not ask for consent f...      1
#
#                              package
# 0  com.realbyteapps.moneymanagerfree
# 1  com.realbyteapps.moneymanagerfree
# 2  com.realbyteapps.moneymanagerfree
# 3  com.realbyteapps.moneymanagerfree
# ...

# %%
new_df3['category'] = 'Finance'
new_df3.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                              content  score  \
# 0  Love the app. Just one suggestion. If we were ...      4
# 1                                      ดีมากๆเลยครับ      5
# 2  It's very much flexible and user friendly.. Lo...      5
# 3                                     Love it so far      5
# 4  Nice app however it does not ask for consent f...      1
#
#                              package category
# 0  com.realbyteapps.moneymanagerfree  Finance
# 1  com.realbyteapps.moneymanagerfree  Finance
# 2  com.realbyteapps.moneymanagerfree  Finance
# ...

# %%
reviews_final4 = reviews_all(
    'com.godutchapp',sleep_milliseconds=0, lang='en', country='us', sort=Sort.NEWEST,
)

df4 = pd.DataFrame(np.array(reviews_final4),columns=['review'])
df4 = df4.join(pd.DataFrame(df4.pop('review').tolist()))

new_df4=df4[['content', 'score']]
new_df4['package'] = 'com.godutchapp'
new_df4.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#                                              content  score         package
# 0  A feature to remind user to make payment on a ...      4  com.godutchapp
# 1  Most of the UPI transactions are marked as 'Ge...      3  com.godutchapp
# 2                            Why you need internet..      1  com.godutchapp
# 3  Its great but I think there's show for improve...      4  com.godutchapp
# 4                     Doesn't work with mobile data.      4  com.godutchapp

# %%
new_df4['category'] = 'Finance'
new_df4.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                              content  score         package  \
# 0  A feature to remind user to make payment on a ...      4  com.godutchapp
# 1  Most of the UPI transactions are marked as 'Ge...      3  com.godutchapp
# 2                            Why you need internet..      1  com.godutchapp
# 3  Its great but I think there's show for improve...      4  com.godutchapp
# 4                     Doesn't work with mobile data.      4  com.godutchapp
#
#   category
# 0  Finance
# 1  Finance
# 2  Finance
# 3  Finance
# 4  Finance

# %%
reviews_final5 = reviews_all(
    'com.womboai.wombodream',sleep_milliseconds=0, lang='en', country='us', sort=Sort.NEWEST,
)

df5 = pd.DataFrame(np.array(reviews_final5),columns=['review'])
df5 = df5.join(pd.DataFrame(df5.pop('review').tolist()))

new_df5=df5[['content', 'score']]
new_df5['package'] = 'com.womboai.wombodream'
new_df5.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#                                              content  score  \
# 0  amazing. great for auto generating image sampl...      5
# 1                                        rad as heck      5
# 2  love it... firstthing I wouldn't mind giving m...      5
# 3  I can finally recreate the dreams I have. I'm ...      5
# 4                                            awesome      5
#
#                   package
# 0  com.womboai.wombodream
# 1  com.womboai.wombodream
# 2  com.womboai.wombodream
# 3  com.womboai.wombodream
# 4  com.womboai.wombodream

# %%
new_df5['category'] = 'Art'
new_df5.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                              content  score  \
# 0  amazing. great for auto generating image sampl...      5
# 1                                        rad as heck      5
# 2  love it... firstthing I wouldn't mind giving m...      5
# 3  I can finally recreate the dreams I have. I'm ...      5
# 4                                            awesome      5
#
#                   package category
# 0  com.womboai.wombodream      Art
# 1  com.womboai.wombodream      Art
# 2  com.womboai.wombodream      Art
# 3  com.womboai.wombodream      Art
# ...

# %%
reviews_final6 = reviews_all(
    'com.adobe.spark.post',sleep_milliseconds=0, lang='en', country='us', sort=Sort.NEWEST,
)

df6 = pd.DataFrame(np.array(reviews_final6),columns=['review'])
df6 = df6.join(pd.DataFrame(df6.pop('review').tolist()))

new_df6=df6[['content', 'score']]
new_df6['package'] = 'com.adobe.spark.post'
new_df6.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#                                              content  score  \
# 0                                 great and Easy!!!!      5
# 1                      good app for design tee-shirt      3
# 2                            Amazing app easy to use      5
# 3  extremely user friendly. great collection of p...      5
# 4  Now they're charging to resize Images that use...      2
#
#                 package
# 0  com.adobe.spark.post
# 1  com.adobe.spark.post
# 2  com.adobe.spark.post
# 3  com.adobe.spark.post
# 4  com.adobe.spark.post

# %%
new_df6['category'] = 'Art'
new_df6.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                              content  score  \
# 0                                 great and Easy!!!!      5
# 1                      good app for design tee-shirt      3
# 2                            Amazing app easy to use      5
# 3  extremely user friendly. great collection of p...      5
# 4  Now they're charging to resize Images that use...      2
#
#                 package category
# 0  com.adobe.spark.post      Art
# 1  com.adobe.spark.post      Art
# 2  com.adobe.spark.post      Art
# 3  com.adobe.spark.post      Art
# 4  com.adobe.spark.post      Art

# %%
reviews_final8 = reviews_all(
    'com.teamviewer.pilot',sleep_milliseconds=0, lang='en', country='us', sort=Sort.NEWEST,
)

df8 = pd.DataFrame(np.array(reviews_final8),columns=['review'])
df8 = df8.join(pd.DataFrame(df8.pop('review').tolist()))

new_df8=df8[['content', 'score']]
new_df8['package'] = 'com.teamviewer.pilot'
new_df8.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#                                              content  score  \
# 0  Team viewer is good 👍 especially if you're the...      4
# 1  At first everything was working as advised nex...      1
# 2                                      Muy buena APP      5
# 3                           Very helpful when Needed      5
# 4                 Amazing innovation by team viewer!      5
#
#                 package
# 0  com.teamviewer.pilot
# 1  com.teamviewer.pilot
# 2  com.teamviewer.pilot
# 3  com.teamviewer.pilot
# 4  com.teamviewer.pilot

# %%
new_df8['category'] = 'AR'
new_df8.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                              content  score  \
# 0  Team viewer is good 👍 especially if you're the...      4
# 1  At first everything was working as advised nex...      1
# 2                                      Muy buena APP      5
# 3                           Very helpful when Needed      5
# 4                 Amazing innovation by team viewer!      5
#
#                 package category
# 0  com.teamviewer.pilot       AR
# 1  com.teamviewer.pilot       AR
# 2  com.teamviewer.pilot       AR
# 3  com.teamviewer.pilot       AR
# 4  com.teamviewer.pilot       AR

# %%
reviews_final9 = reviews_all(
    'care.jivaka.picky',sleep_milliseconds=0, lang='en', country='us', sort=Sort.NEWEST,
)

df9 = pd.DataFrame(np.array(reviews_final9),columns=['review'])
df9 = df9.join(pd.DataFrame(df9.pop('review').tolist()))

new_df9=df9[['content', 'score']]
new_df9['package'] = 'care.jivaka.picky'
new_df9.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#                                              content  score            package
# 0  Deleted the app because it wouldn't allow me t...      1  care.jivaka.picky
# 1  I can spend all day on this app honestly. It's...      5  care.jivaka.picky
# 2  This is one of the best app ever real people t...      5  care.jivaka.picky
# 3  Everything is fine but disappointing me at the...      2  care.jivaka.picky
# 4  Wonderful App, Amazing Community of friendly, ...      5  care.jivaka.picky

# %%
new_df9['category'] = 'Beauty'
new_df9.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                              content  score  \
# 0  Deleted the app because it wouldn't allow me t...      1
# 1  I can spend all day on this app honestly. It's...      5
# 2  This is one of the best app ever real people t...      5
# 3  Everything is fine but disappointing me at the...      2
# 4  Wonderful App, Amazing Community of friendly, ...      5
#
#              package category
# 0  care.jivaka.picky   Beauty
# 1  care.jivaka.picky   Beauty
# 2  care.jivaka.picky   Beauty
# 3  care.jivaka.picky   Beauty
# 4  care.jivaka.picky   Beauty

# %%
reviews_final10 = reviews_all(
    'com.app.sugarcosmetics',sleep_milliseconds=0, lang='en', country='us', sort=Sort.NEWEST,
)

df10 = pd.DataFrame(np.array(reviews_final10),columns=['review'])
df10 = df10.join(pd.DataFrame(df10.pop('review').tolist()))

new_df10=df10[['content', 'score']]
new_df10['package'] = 'com.app.sugarcosmetics'
new_df10.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#                                              content  score  \
# 0  Just bad lipsticks!!!! I bought soooooo many l...      1
# 1                                            average      1
# 2                         wowwwww amazing product...      5
# 3                             good very nice product      4
# 4                      excellent product. I like it.      5
#
#                   package
# 0  com.app.sugarcosmetics
# 1  com.app.sugarcosmetics
# 2  com.app.sugarcosmetics
# 3  com.app.sugarcosmetics
# 4  com.app.sugarcosmetics

# %%
new_df10['category'] = 'Beauty'
new_df10.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                              content  score  \
# 0  Just bad lipsticks!!!! I bought soooooo many l...      1
# 1                                            average      1
# 2                         wowwwww amazing product...      5
# 3                             good very nice product      4
# 4                      excellent product. I like it.      5
#
#                   package category
# 0  com.app.sugarcosmetics   Beauty
# 1  com.app.sugarcosmetics   Beauty
# 2  com.app.sugarcosmetics   Beauty
# 3  com.app.sugarcosmetics   Beauty
# ...

# %%
reviews_final11 = reviews_all(
    'org.wikipedia',sleep_milliseconds=0, lang='en', country='us', sort=Sort.NEWEST,
)

df11 = pd.DataFrame(np.array(reviews_final11),columns=['review'])
df11 = df11.join(pd.DataFrame(df11.pop('review').tolist()))

new_df11=df11[['content', 'score']]
new_df11['package'] = 'org.wikipedia'
new_df11.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#                                              content  score        package
# 0  Bias is an understatement. Actually adopts the...      1  org.wikipedia
# 1  Jimmy Wales deserves my $3, and one day I inte...      5  org.wikipedia
# 2  Thanks for making this app GOD bless you. I ho...      5  org.wikipedia
# 3       One of the best information app you can get!      5  org.wikipedia
# 4                                          great app      5  org.wikipedia

# %%
new_df11['category'] = 'Books'
new_df11.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                              content  score        package  \
# 0  Bias is an understatement. Actually adopts the...      1  org.wikipedia
# 1  Jimmy Wales deserves my $3, and one day I inte...      5  org.wikipedia
# 2  Thanks for making this app GOD bless you. I ho...      5  org.wikipedia
# 3       One of the best information app you can get!      5  org.wikipedia
# 4                                          great app      5  org.wikipedia
#
#   category
# 0    Books
# 1    Books
# 2    Books
# 3    Books
# 4    Books

# %%
reviews_final12 = reviews_all(
    'com.google.android.apps.books',sleep_milliseconds=0, lang='en', country='us', sort=Sort.NEWEST,
)

df12 = pd.DataFrame(np.array(reviews_final12),columns=['review'])
df12 = df12.join(pd.DataFrame(df12.pop('review').tolist()))

new_df12=df12[['content', 'score']]
new_df12['package'] = 'com.google.android.apps.books'
new_df12.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#                                              content  score  \
# 0                                                 Uu      5
# 1                                               Nice      5
# 2                                         आरटीटीयू5t      4
# 3  There is a certain ebook that no matter how ha...      4
# 4                                        Excellent 👍      5
#
#                          package
# 0  com.google.android.apps.books
# 1  com.google.android.apps.books
# 2  com.google.android.apps.books
# 3  com.google.android.apps.books
# 4  com.google.android.apps.books

# %%
new_df12['category'] = 'Books'
new_df12.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                              content  score  \
# 0                                                 Uu      5
# 1                                               Nice      5
# 2                                         आरटीटीयू5t      4
# 3  There is a certain ebook that no matter how ha...      4
# 4                                        Excellent 👍      5
#
#                          package category
# 0  com.google.android.apps.books    Books
# 1  com.google.android.apps.books    Books
# 2  com.google.android.apps.books    Books
# ...

# %%
reviews_final13 = reviews_all(
    'com.glassdoor.app',sleep_milliseconds=0, lang='en', country='us', sort=Sort.NEWEST,
)

df13 = pd.DataFrame(np.array(reviews_final13),columns=['review'])
df13 = df13.join(pd.DataFrame(df13.pop('review').tolist()))

new_df13=df13[['content', 'score']]
new_df13['package'] = 'com.glassdoor.app'
new_df13.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#                                              content  score            package
# 0  Total bakwas app, it won't open at all,can't s...      1  com.glassdoor.app
# 1                           not so good experience 😕      1  com.glassdoor.app
# 2  It is impossible to apply to a job on here, ev...      1  com.glassdoor.app
# 3  No experience Am hard work and can do lifting ...      3  com.glassdoor.app
# 4  Can you include search filter by star rating? ...      4  com.glassdoor.app

# %%
new_df13['category'] = 'Business'
new_df13.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                              content  score  \
# 0  Total bakwas app, it won't open at all,can't s...      1
# 1                           not so good experience 😕      1
# 2  It is impossible to apply to a job on here, ev...      1
# 3  No experience Am hard work and can do lifting ...      3
# 4  Can you include search filter by star rating? ...      4
#
#              package  category
# 0  com.glassdoor.app  Business
# 1  com.glassdoor.app  Business
# 2  com.glassdoor.app  Business
# 3  com.glassdoor.app  Business
# 4  com.glassdoor.app  Business

# %%
reviews_final14 = reviews_all(
    'com.fiverr.fiverr',sleep_milliseconds=0, lang='en', country='us', sort=Sort.NEWEST,
)

df14 = pd.DataFrame(np.array(reviews_final14),columns=['review'])
df14 = df14.join(pd.DataFrame(df14.pop('review').tolist()))

new_df14=df14[['content', 'score']]
new_df14['package'] = 'com.fiverr.fiverr'
new_df14.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#                                              content  score            package
# 0                Good app for finding right tech guy      5  com.fiverr.fiverr
# 1  Buyer placed an order for the service which is...      1  com.fiverr.fiverr
# 2  Highly professional and dedicated team. I woul...      5  com.fiverr.fiverr
# 3  Unable to make delivery. Even trying multiple ...      1  com.fiverr.fiverr
# 4                                           Good app      5  com.fiverr.fiverr

# %%
new_df14['category'] = 'Business'
new_df14.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                              content  score  \
# 0                Good app for finding right tech guy      5
# 1  Buyer placed an order for the service which is...      1
# 2  Highly professional and dedicated team. I woul...      5
# 3  Unable to make delivery. Even trying multiple ...      1
# 4                                           Good app      5
#
#              package  category
# 0  com.fiverr.fiverr  Business
# 1  com.fiverr.fiverr  Business
# 2  com.fiverr.fiverr  Business
# 3  com.fiverr.fiverr  Business
# 4  com.fiverr.fiverr  Business

# %%
reviews_final15 = reviews_all(
    'com.naver.linewebtoon',sleep_milliseconds=0, lang='en', country='us', sort=Sort.NEWEST,
)

df15 = pd.DataFrame(np.array(reviews_final15),columns=['review'])
df15 = df15.join(pd.DataFrame(df15.pop('review').tolist()))

new_df15=df15[['content', 'score']]
new_df15['package'] = 'com.naver.linewebtoon'
new_df15.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#                                              content  score  \
# 0  I've been having an issue with the app for a f...      2
# 1                     thiss app...i give it 5 S rank      5
# 2    I really really like this apo I enjoyed reading      5
# 3  It's good but everytime I want to log in it sa...      5
# 4  LOVE IT! Each character is someone you can lov...      5
#
#                  package
# 0  com.naver.linewebtoon
# 1  com.naver.linewebtoon
# 2  com.naver.linewebtoon
# 3  com.naver.linewebtoon
# 4  com.naver.linewebtoon

# %%
new_df15['category'] = 'Comics'
new_df15.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                              content  score  \
# 0  I've been having an issue with the app for a f...      2
# 1                     thiss app...i give it 5 S rank      5
# 2    I really really like this apo I enjoyed reading      5
# 3  It's good but everytime I want to log in it sa...      5
# 4  LOVE IT! Each character is someone you can lov...      5
#
#                  package category
# 0  com.naver.linewebtoon   Comics
# 1  com.naver.linewebtoon   Comics
# 2  com.naver.linewebtoon   Comics
# 3  com.naver.linewebtoon   Comics
# ...

# %%
reviews_final16 = reviews_all(
    'com.bilibili.comic.intl',sleep_milliseconds=0, lang='en', country='us', sort=Sort.NEWEST,
)

df16 = pd.DataFrame(np.array(reviews_final16),columns=['review'])
df16 = df16.join(pd.DataFrame(df16.pop('review').tolist()))

new_df16=df16[['content', 'score']]
new_df16['package'] = 'com.bilibili.comic.intl'
new_df16.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#                                              content  score  \
# 0                             ❤❤❤❤💜💜💜💜💖💖💖💖💖🤩🤩🤩🤩🥰🥰🥰🥰🥰      5
# 1           The drawing and the humor is too good ☺️      5
# 2  It's good and all BUT PLEASE HELP ME CHANGE MY...      1
# 3                             Love the stories ❤ 💕 ♥      4
# 4                  It was very interesting I love it      5
#
#                    package
# 0  com.bilibili.comic.intl
# 1  com.bilibili.comic.intl
# 2  com.bilibili.comic.intl
# 3  com.bilibili.comic.intl
# 4  com.bilibili.comic.intl

# %%
new_df16['category'] = 'Comics'
new_df16.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                              content  score  \
# 0                             ❤❤❤❤💜💜💜💜💖💖💖💖💖🤩🤩🤩🤩🥰🥰🥰🥰🥰      5
# 1           The drawing and the humor is too good ☺️      5
# 2  It's good and all BUT PLEASE HELP ME CHANGE MY...      1
# 3                             Love the stories ❤ 💕 ♥      4
# 4                  It was very interesting I love it      5
#
#                    package category
# 0  com.bilibili.comic.intl   Comics
# 1  com.bilibili.comic.intl   Comics
# 2  com.bilibili.comic.intl   Comics
# 3  com.bilibili.comic.intl   Comics
# ...

# %%
reviews_final17 = reviews_all(
    'org.thoughtcrime.securesms',sleep_milliseconds=0, lang='en', country='us', sort=Sort.NEWEST,
)

df17 = pd.DataFrame(np.array(reviews_final17),columns=['review'])
df17 = df17.join(pd.DataFrame(df17.pop('review').tolist()))

new_df17=df17[['content', 'score']]
new_df17['package'] = 'org.thoughtcrime.securesms'
new_df17.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#                                              content  score  \
# 0                            New interface is great.      5
# 1           Dawanlod problem and voice break problem      1
# 2  All the advice was signal is best default sms ...      2
# 3                                 Best......easy....      5
# 4  Why update again and again.??????....chk the a...      2
#
#                       package
# 0  org.thoughtcrime.securesms
# 1  org.thoughtcrime.securesms
# 2  org.thoughtcrime.securesms
# 3  org.thoughtcrime.securesms
# 4  org.thoughtcrime.securesms

# %%
new_df17['category'] = 'Communication'
new_df17.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                              content  score  \
# 0                            New interface is great.      5
# 1           Dawanlod problem and voice break problem      1
# 2  All the advice was signal is best default sms ...      2
# 3                                 Best......easy....      5
# 4  Why update again and again.??????....chk the a...      2
#
#                       package       category
# 0  org.thoughtcrime.securesms  Communication
# 1  org.thoughtcrime.securesms  Communication
# 2  org.thoughtcrime.securesms  Communication
# ...

# %%
reviews_final18 = reviews_all(
    'com.brave.browser',sleep_milliseconds=0, lang='en', country='us', sort=Sort.NEWEST,
)

df18 = pd.DataFrame(np.array(reviews_final18),columns=['review'])
df18 = df18.join(pd.DataFrame(df18.pop('review').tolist()))

new_df18=df18[['content', 'score']]
new_df18['package'] = 'com.brave.browser'
new_df18.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#                                              content  score            package
# 0  This application sometimes make wrongs but usu...      5  com.brave.browser
# 1                      Definition of excellence ....      5  com.brave.browser
# 2                                    Good experience      5  com.brave.browser
# 3  The best Browser app I've ever seen! It's free...      5  com.brave.browser
# 4             GET TOUGH with internet....about time!      5  com.brave.browser

# %%
new_df18['category'] = 'Communication'
new_df18.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                              content  score  \
# 0  This application sometimes make wrongs but usu...      5
# 1                      Definition of excellence ....      5
# 2                                    Good experience      5
# 3  The best Browser app I've ever seen! It's free...      5
# 4             GET TOUGH with internet....about time!      5
#
#              package       category
# 0  com.brave.browser  Communication
# 1  com.brave.browser  Communication
# 2  com.brave.browser  Communication
# 3  com.brave.browser  Communication
# ...

# %%
new_frame = [new_df, new_df2,new_df3,new_df4,new_df5,new_df6,new_df8,new_df9,new_df10,new_df11,new_df12,new_df13,new_df14,new_df15,new_df16,new_df17,new_df18]
  
final_df = pd.concat(new_frame)
final_df.head()
# Out:
#                                              content  score          package  \
# 0                                   Good application      5  com.sportstoday
# 1                                  Working very slow      1  com.sportstoday
# 2  Love from Nepal Vikrant sir&whole team of spor...      5  com.sportstoday
# 3                                                Kgf      5  com.sportstoday
# 4                                  Luv u vikrant sir      5  com.sportstoday
#
#   category
# 0   Sports
# 1   Sports
# 2   Sports
# 3   Sports
# 4   Sports

# %%
final_df.tail()
# Out:
#                                                   content  score  \
# 151667     Blocks ads efficiently and pages load quickly.      5
# 151668        Brave "for people who stand and fight back"      5
# 151669  The Android version of chrome except with ever...      5
# 151670                                           Love it!      5
# 151671     fast, no ads, free, open source software 🦁🦁🦁🦁🦁      5
#
#                   package       category
# 151667  com.brave.browser  Communication
# 151668  com.brave.browser  Communication
# 151669  com.brave.browser  Communication
# 151670  com.brave.browser  Communication
# 151671  com.brave.browser  Communication

# %%
final_df.to_csv('reviews.csv')

# %%
final_df=final_df.dropna()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer

# %%
df_1 = pd.read_csv('reviews.csv')
df_1.head()
# Out:
#    Unnamed: 0                                            content  score  \
# 0           0                                   Good application      5
# 1           1                                  Working very slow      1
# 2           2  Love from Nepal Vikrant sir&whole team of spor...      5
# 3           3                                                Kgf      5
# 4           4                                  Luv u vikrant sir      5
#
#            package category
# 0  com.sportstoday   Sports
# 1  com.sportstoday   Sports
# 2  com.sportstoday   Sports
# 3  com.sportstoday   Sports
# 4  com.sportstoday   Sports

# %%
def data_clean(data):
    data = data.drop('Unnamed: 0', axis=1)
    data['content'] = data['content'].str.strip().str.lower()
    return data

df_1 = data_clean(df_1)

# %%
df_1.head()
# Out:
#                                              content  score          package  \
# 0                                   good application      5  com.sportstoday
# 1                                  working very slow      1  com.sportstoday
# 2  love from nepal vikrant sir&whole team of spor...      5  com.sportstoday
# 3                                                kgf      5  com.sportstoday
# 4                                  luv u vikrant sir      5  com.sportstoday
#
#   category
# 0   Sports
# 1   Sports
# 2   Sports
# 3   Sports
# 4   Sports

# %% [markdown]
# 1 means score>=3, 0 means score of 1 or 2

# %%
df_1['y'] = np.where(df_1['score']>=3, 1, 0)
df_1.head()
# Out:
#                                              content  score          package  \
# 0                                   good application      5  com.sportstoday
# 1                                  working very slow      1  com.sportstoday
# 2  love from nepal vikrant sir&whole team of spor...      5  com.sportstoday
# 3                                                kgf      5  com.sportstoday
# 4                                  luv u vikrant sir      5  com.sportstoday
#
#   category  y
# 0   Sports  1
# 1   Sports  0
# 2   Sports  1
# 3   Sports  1
# 4   Sports  1
